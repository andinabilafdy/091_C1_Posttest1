# %% [markdown]
# <a href="https://colab.research.google.com/github/andinabilafdy/091_C1_Posttest1/blob/main/C1_091_Posttest_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# POSTTEST 1 DATA MINING

# %% [markdown]
# Nama : Andi Nabila Fadiya
#
# NIM : 2109116091
#
# Kelas : C1 2021

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# #Business Understanding

# %% [markdown]
# **Tujuan penggunaan dataset :** Untuk mengumpulkan informasi dan data terpercaya sebanyak-banyaknya yang kemudian dianalisis untuk membuat sebuah keputusan bisnis yang krusial pada perusahaan agar tidak terjadi misskomunikasi.

# %% [markdown]
# **Tujuan perusahaan :** Dataset diperlukan untuk membuat keputusan bisnis perusahaan. Sehingga dengan dataset yang dibuat perusahaan dapat mengetahui tren pasar, memprediksi keputusan bisnis di masa mendatang, mengetahui produk yang sedang viral, mengamati perilaku konsumen, dan sebagai sarana menyusun strategi peningkatan penjualan.

# %% [markdown]
# **Tujuan penggunaan Naive Bayes :** Untuk mengklasifikasikan probabilitas berdasarkana machine learning atas probabilitas lainnya, melakukan klasifikasi data pada kelas tertentu, kemudian pola tersebut dapat digunakan untuk memperkirakan nasabah yang bergabung sehingga perusahaan bisa mengambil keputusan menerima atau menolak calon nasabah tersebut.
# Juga untuk menganalisis tindak penipuan internal perusahaan. Mereka mempelajari probabilitas reimburse yang sesuai untuk kemudian memprediksi probabilitas reimburse yang dilebih-lebihkan

# %% [markdown]
# #Data Understanding

# %%
 # dataset dengan label target AttiredCustomer

df[df.Attrition_Flag == "Attrited Customer"]
df_1 = df.Attrition_Flag == "Attrited Customer"

# %%
df[df_1]
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
# label bukan Attrired customer

df_2 = df.Attrition_Flag == "Attrited Customer"

# %%
df[~df_2]
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# tabel untuk usia dibawah 50 tahun

df_3 = df[df['Customer_Age'] < 50]

# %%
df_3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# customer yang statusnya itu single

df_4 = df.Marital_Status == "Single"

# %%
df[df_4]
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# Penjelasan : Pada hasil df.info menjelaskan terdapat jumlah data sebanyak 20 yang terbagi dalam 10 kolom, jumlah tipe data float 1, int 3 dan object 6.

# %% [markdown]
# # Opsional 1

# %% [markdown]
# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka

# %%
# Kolom Unnamed: 0

df_5 = df.agg({"Unnamed: 0": ["mean", "min", "max", "std"]})

# %%
df_5
# Out:
#         Unnamed: 0
# mean   6105.100000
# min     176.000000
# max   10084.000000
# std    2850.304026

# %%
# Kolom CLIENTNUM

df_6 = df.agg({"CLIENTNUM": ["mean", "min", "max", "std"]})

# %%
df_6
# Out:
#          CLIENTNUM
# mean  7.424893e+08
# min   7.092220e+08
# max   8.098441e+08
# std   4.045524e+07

# %%
# Kolom Customer_Age

df_7 = df.agg({"Customer_Age": ["mean", "min", "max", "std"]})

# %%
df_7
# Out:
#       Customer_Age
# mean     47.250000
# min      32.000000
# max      59.000000
# std       7.859791

# %%
# Kolom Credit_Limit

df_8 = df.agg({"Credit_Limit": ["mean", "min", "max", "std"]})

# %%
df_8
# Out:
#       Credit_Limit
# mean   8114.580000
# min    1438.300000
# max   26792.000000
# std    8331.036819

# %% [markdown]
# #Explore Data

# %% [markdown]
# # Visualisasi Comparison

# %%
# Visualisasi yang menampilkan berapa banyak yang attired customer dan tidak

sns.countplot(data=df, x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %% [markdown]
# Penjelasan : Sumbu x merupakan kategori yang muncul pada kolom "Attrition_Flag" (yaitu "Attrited Customer" dan "Existing Customer"), sedangkan sumbu y menunjukkan jumlah berapa banyak data yang terdapat pada masing-masing kategori tersebut. Warna biru menunjukkan berapa banyak jumlah "Attrited Customer" yaitu 10 data, sedangkan warna oranye menunjukkan menunjukkan berapa banyak jumlah "Existing Customer" yaitu 10 data juga.

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
# contoh Unknown berapa dsb

px.histogram(df, x="Education_Level", color="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Penjelasan : Sumbu x menunjukkan kategori pada kolom "Education_Level", (yaitu "Unknown", "Uneducated", "College", "High school", "Graduate", "Post-Graduade", dan "Doctorate"), sedangkan sumbu y menunjukkan jumlah berapa banyak data yang terdapat pada masing-masing kategori tersebut. Terdapat 2 data kategori "Unknown", 5 data kategori "Uneducated", 1 data kategori "College", 4 data kategori "High School", 5 data kategori "Graduate", 2 data kategori "Post-Graduate", dan 1 data kategori "Doctorate".

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
# contoh M berapa F berapa

sns.countplot(data=df, x="Gender", hue="Education_Level")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Penjelasan : Sumbu x menunjukkan kategori Education_Level berdasarkan pada "Gender", (yaitu "M" dan "F"), sedangkan sumbu y menunjukkan berapa banyak data yang terdapat pada masing-masing kategori tersebut.
# Warna biru menunjukkan kategori "Unknown"(M = 2 data, F = 0),
# warna oranye kategori "Uneducated" (M = 3 data, F = 2 data),
# warna hijau kategori "College" (M = 1 data, F = 0),
# warna merah kategori "High School" (M = 2 data, F = 2 data),
# warna ungu kategori "Graduate" (M = 1 data, F = 4 data),
# warna coklat kategori "Post-Graduate" (M = 1 data, F = 1 data),
# warna pink kategori "Doctorate" (M = 1 data, F = 0).

# %% [markdown]
# # Visualisasi Distribution

# %%
# Histogram untuk customer age

px.histogram(df, x="Customer_Age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Penjelasan : Sumbu x menunjukkan distribusi rentang usia pada data Customer_Age, sedangkan sumbu y menunjukkan banyaknya jumlah data pada rentang usia.
# Terdapat 1 data Customer_Age pada rentang usia 30 - 34 tahun, 2 data pada rentang usia 35-39 tahun, 5 data pada rentang usia 40-44 tahun, 4 data pada rentang usia 45-49 tahun, 3 data pada rentang usia 50-54 tahun, dan 5 data pada rentang usia 55-59 tahun

# %%
# Histrogram untuk credit card limit

px.histogram(df, x="Credit_Limit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Penjelasan : Sumbu x menunjukkan distribusi Credit_Limit, sedangkan sumbu y menunjukkan banyaknya jumlah data. Terdapat 11 data Credit_Limit pada rentang 0-4,9k, 4 data pada rentang 5k-9,9k, 1 data pada rentang 10k-14,9k, 1 data pada rentang 15k-19,9k, 2 data pada rentang 20k-24,9k, 1 data pada rentang 25k-29,9k, dan 1 data pada rentang 25k-29,9k.

# %%
# Boxplot Customer Age

px.box(df, x="Customer_Age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Penjelasan : Sumbu y menunjukkan rentang usia pada data "Customer_Age". Boxplot tersebut menunjukkan distribusi data usia customer pada dataframe, dengan garis tengah (median) pada nilai 47,5, quartile 1 (Q1) pada nilai 41, quartile 3 (Q3) pada nilai 54, min pada nilai 32, dan max pada nilai 59.

# %%
# Boxplot Credit Card Limit

px.box(df, x="Credit_Limit")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Penjelasan : Sumbu y menunjukkan rentang nilai pada "Credit_Limit". Boxplot tersebut menunjukkan distribusi data credit limit pada dataframe, dengan garis tengah (median) pada nilai 4,118.5, quartile 1 (Q1) pada nilai 2478, quartile 3 (Q3) pada nilai 9156, min pada nilai 1,438.3, dan max pada nilai 26.792k

# %% [markdown]
# # Visualisasi Relationship

# %%
# scatterplot untuk umur customer dan credit card limit

sns.scatterplot(data=df, x="Customer_Age", y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# # Visualisasi Composition

# %%
# pieplot untuk Income Category

px.pie(df, names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# pieplot untuk Education Level

px.pie(df, names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Optional 2

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)

sns.boxplot(data=df, x="Credit_Limit", y="Gender")
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Gender'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)

sns.boxplot(data=df, x="Credit_Limit", y="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)

sns.boxplot(data=df, x="Customer_Age", y="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Attrition_Flag'>

# %%
# visualisasi countplot Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)

sns.countplot(data=df, x="Attrition_Flag", hue="Gender")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada

sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# mengambil dataset df
df = pd.read_csv("ChurnBank.csv")
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)

data = df.drop(['Unnamed: 0' , 'CLIENTNUM' , 'Customer_Age' , 'Credit_Limit'], axis=1)

# %%
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

dfnew = pd.DataFrame(data)
dfnew
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Pindah data Attrition_Flag ke kolom ujung kanan
cols = dfnew.columns.tolist()
cols.remove("Attrition_Flag")
cols.append("Attrition_Flag")
dfnew = dfnew[cols]

# Hitung jumlah data training dan data testing
N_train = len(dfnew)

# Hitung jumlah target
target_counts = dfnew.groupby("Attrition_Flag")["Attrition_Flag"].count()

# Hitung prior probability untuk setiap target
prob_prio = target_counts/N_train

# Hitung conditional probability untuk setiap target
prob_kond = {}
for col in dfnew.columns[:-1]:
  prob_kond[col] = {}
  for val in dfnew[col].unique():
    for target in dfnew["Attrition_Flag"].unique():
      count = len(df[(df[col] == val) & (dfnew["Attrition_Flag"] == target)])
      prob_kond[col][(val,target)] = count/target_counts[target]

# Fungsi Naive_Bayes
def naive_bayes(a):
  prob_yes = prob_prio["Attrited Customer"]
  prob_no = prob_prio["Existing Customer"]
  for i, col in enumerate(dfnew.columns[:-1]):
    prob_yes *= prob_kond[col][(a[i], "Attrited Customer")]
    prob_no *= prob_kond[col][(a[i], "Existing Customer")]

  if prob_yes < prob_no:
    hasil = "Attrited Customer", prob_yes
  else:
    hasil = "Existing Customer", prob_no
  return hasil

# %%
output = naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
print("Output : ", output)
# Out:
# Output :  ('Attrited Customer', 0.0018)
